# %% [markdown]
# Notebook: Feature Selection and Data Cleaning
# Purpose:
# - Select relevant features for predicting energy_per_capita.
# - Filter dataset by year and countries with sufficient data.
# - Drop rows with missing target.
# - Impute remaining missing values in GDP and energy share features.

# %%
# -------------------------------
# 1. Imports
# -------------------------------
import pandas as pd

# -------------------------------
# 2. Load Dataset
# -------------------------------
url = "https://raw.githubusercontent.com/JiaLiiin/CS506-Project/refs/heads/proposal-update/Data/owid-energy-data-updated.csv"
df = pd.read_csv(url)

print(df.shape)
print(list(df.columns))
# Out:
# (14384, 130)
# ['country', 'year', 'iso_code', 'population', 'biofuel_cons_change_pct', 'biofuel_cons_change_twh', 'biofuel_cons_per_capita', 'biofuel_consumption', 'biofuel_elec_per_capita', 'biofuel_electricity', 'biofuel_share_elec', 'biofuel_share_energy', 'carbon_intensity_elec', 'coal_cons_change_pct', 'coal_cons_change_twh', 'coal_cons_per_capita', 'coal_consumption', 'coal_elec_per_capita', 'coal_electricity', 'coal_prod_change_pct', 'coal_prod_change_twh', 'coal_prod_per_capita', 'coal_production', 'coal_share_elec', 'coal_share_energy', 'electricity_demand', 'electricity_demand_per_capita', 'electricity_generation', 'electricity_share_energy', 'energy_cons_change_pct', 'energy_cons_change_twh', 'energy_per_capita', 'energy_per_gdp', 'fossil_cons_change_pct', 'fossil_cons_change_twh', 'fossil_elec_per_capita', 'fossil_electricity', 'fossil_energy_per_capita', 'fossil_fuel_consumption', 'fossil_share_elec', 'fossil_share_energy', 'gas_cons_change_pct', 'gas_cons_change_twh', 'gas_consumption', 'gas_elec_per_capita', 'gas_electricity', 'gas_energy_per_capita', 'gas_prod_change_pct', 'gas_prod_change_twh', 'gas_prod_per_capita', 'gas_production', 'gas_share_elec', 'gas_share_energy', 'greenhouse_gas_emissions', 'hydro_cons_change_pct', 'hydro_cons_change_twh', 'hydro_consumption', 'hydro_elec_per_capita', 'hydro_electricity', 'hydro_energy_per_capita', 'hydro_share_elec', 'hydro_share_energy', 'low_carbon_cons_change_pct', 'low_carbon_cons_change_twh', 'low_carbon_consumption', 'low_carbon_elec_per_capita', 'low_carbon_electricity', 'low_carbon_energy_per_capita', 'low_carbon_share_elec', 'low_carbon_share_energy', 'net_elec_imports', 'net_elec_imports_share_demand', 'nuclear_cons_change_pct', 'nuclear_cons_change_twh', 'nuclear_consumption', 'nuclear_elec_per_capita', 'nuclear_electricity', 'nuclear_energy_per_capita', 'nuclear_share_elec', 'nuclear_share_energy', 'oil_cons_change_pct', 'oil_cons_change_twh', 'oil_consumption', 'oil_elec_per_capita', 'oil_electricity', 'oil_energy_per_capita', 'oil_prod_change_pct', 'oil_prod_change_twh', 'oil_prod_per_capita', 'oil_production', 'oil_share_elec', 'oil_share_energy', 'other_renewable_consumption', 'other_renewable_electricity', 'other_renewable_exc_biofuel_electricity', 'other_renewables_cons_change_pct', 'other_renewables_cons_change_twh', 'other_renewables_elec_per_capita', 'other_renewables_elec_per_capita_exc_biofuel', 'other_renewables_energy_per_capita', 'other_renewables_share_elec', 'other_renewables_share_elec_exc_biofuel', 'other_renewables_share_energy', 'per_capita_electricity', 'primary_energy_consumption', 'renewables_cons_change_pct', 'renewables_cons_change_twh', 'renewables_consumption', 'renewables_elec_per_capita', 'renewables_electricity', 'renewables_energy_per_capita', 'renewables_share_elec', 'renewables_share_energy', 'solar_cons_change_pct', 'solar_cons_change_twh', 'solar_consumption', 'solar_elec_per_capita', 'solar_electricity', 'solar_energy_per_capita', 'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct', 'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita', 'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec', 'wind_share_energy', 'gdp']

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# biofuel_cons_change_pct             0.919494
# nuclear_cons_change_pct             0.902461
# solar_cons_change_pct               0.896065
# wind_cons_change_pct                0.885498
# other_renewables_cons_change_pct    0.836902
#                                       ...
# oil_production                      0.187848
# iso_code                            0.019118
# population                          0.006257
# year                                0.000000
# country                             0.000000
# Length: 130, dtype: float64

# %%
# -------------------------------
# 3. Feature Selection
# -------------------------------
selected_columns = [
    "country", "year",
    "population", "gdp",
    "energy_per_capita",
    "coal_cons_per_capita", "gas_energy_per_capita", "oil_energy_per_capita",
    "fossil_energy_per_capita", "fossil_share_energy",
    "renewables_energy_per_capita", "low_carbon_energy_per_capita",
    "renewables_share_energy", "low_carbon_share_energy",
    "hydro_share_energy", "solar_share_energy", "wind_share_energy"
]

df_selected = df[selected_columns].copy()

# Compute GDP per capita
df_selected["gdp_per_capita"] = df_selected["gdp"] / df_selected["population"]

df_selected.head()
# Out:
#        country  year  population  gdp  energy_per_capita  \
# 0  Afghanistan  1900   4707744.0  NaN                NaN
# 1  Afghanistan  1901   4751177.0  NaN                NaN
# 2  Afghanistan  1902   4802500.0  NaN                NaN
# 3  Afghanistan  1903   4861833.0  NaN                NaN
# 4  Afghanistan  1904   4921891.0  NaN                NaN
#
#    coal_cons_per_capita  gas_energy_per_capita  oil_energy_per_capita  \
# 0                   NaN                    NaN                    NaN
# 1                   NaN                    NaN                    NaN
# 2                   NaN                    NaN                    NaN
# 3                   NaN                    NaN                    NaN
# 4                   NaN                    NaN                    NaN
#
#    fossil_energy_per_capita  fossil_share_energy  \
# 0                       NaN                  NaN
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
#
#    renewables_energy_per_capita  low_carbon_energy_per_capita  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    renewables_share_energy  low_carbon_share_energy  hydro_share_energy  \
# 0                      NaN                      NaN                 NaN
# 1                      NaN                      NaN                 NaN
# 2                      NaN                      NaN                 NaN
# 3                      NaN                      NaN                 NaN
# 4                      NaN                      NaN                 NaN
#
#    solar_share_energy  wind_share_energy  gdp_per_capita
# 0                 NaN                NaN             NaN
# 1                 NaN                NaN             NaN
# 2                 NaN                NaN             NaN
# 3                 NaN                NaN             NaN
# 4                 NaN                NaN             NaN

# %%
df_selected.groupby("year").apply(lambda x: x.isna().mean().mean())
# Out:
# /tmp/ipykernel_4381/1718478326.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_selected.groupby("year").apply(lambda x: x.isna().mean().mean())
# year
# 1900    0.833333
# 1901    0.834688
# 1902    0.834688
# 1903    0.834688
# 1904    0.834688
#           ...
# 2020    0.400816
# 2021    0.401444
# 2022    0.401444
# 2023    0.403327
# 2024    0.249486
# Length: 125, dtype: float64

# %%
df_selected.groupby("country").apply(lambda x: x.isna().mean().mean()).sort_values(ascending=False)
# Out:
# /tmp/ipykernel_4381/3366396661.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_selected.groupby("country").apply(lambda x: x.isna().mean().mean()).sort_values(ascending=False)
# country
# Afghanistan        0.792115
# Curacao            0.787037
# Greenland          0.785394
# Mozambique         0.783556
# Albania            0.774194
#                      ...
# Iceland            0.000000
# North Macedonia    0.000000
# Singapore          0.000000
# Sri Lanka          0.000000
# Slovenia           0.000000
# Length: 177, dtype: float64

# %%
unique_countries = df_selected["country"].unique()
print(unique_countries)
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium'
#  'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia' 'Bosnia and Herzegovina'
#  'Botswana' 'Brazil' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cambodia'
#  'Cameroon' 'Canada' 'Cayman Islands' 'Central African Republic' 'Chad'
#  'Chile' 'China' 'Colombia' 'Comoros' 'Costa Rica' "Cote d'Ivoire"
#  'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark' 'Djibouti'
#  'Dominica' 'Dominican Republic' 'Ecuador' 'El Salvador'
#  'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini' 'Ethiopia'
#  'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia' 'Gabon'
#  'Georgia' 'Germany' 'Ghana' 'Greece' 'Greenland' 'Grenada' 'Guam'
#  'Guatemala' 'Guinea' 'Guinea-Bissau' 'Guyana' 'Haiti' 'Honduras'
#  'Hungary' 'Iceland' 'India' 'Indonesia' 'Iraq' 'Ireland' 'Israel' 'Italy'
#  'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kenya' 'Kiribati' 'Kosovo'
#  'Kuwait' 'Latvia' 'Lebanon' 'Lesotho' 'Liberia' 'Libya' 'Lithuania'
#  'Luxembourg' 'Madagascar' 'Malawi' 'Malaysia' 'Maldives' 'Mali' 'Malta'
#  'Mauritania' 'Mauritius' 'Mexico' 'Moldova' 'Mongolia' 'Montenegro'
#  'Morocco' 'Mozambique' 'Myanmar' 'Namibia' 'Nauru' 'Nepal' 'Netherlands'
#  'New Caledonia' 'New Zealand' 'Nicaragua' 'Niger' 'Nigeria'
#  'North America' 'North Macedonia' 'Northern Mariana Islands' 'Norway'
#  'Oman' 'Pakistan' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru'
#  'Philippines' 'Poland' 'Portugal' 'Qatar' 'Romania' 'Rwanda' 'Samoa'
#  'Sao Tome and Principe' 'Saudi Arabia' 'Senegal' 'Serbia' 'Seychelles'
#  'Sierra Leone' 'Singapore' 'Slovenia' 'Solomon Islands' 'South Africa'
#  'South Sudan' 'Spain' 'Sri Lanka' 'Sudan' 'Suriname' 'Sweden'
#  'Switzerland' 'Tajikistan' 'Tanzania' 'Thailand' 'Togo' 'Tonga'
#  'Trinidad and Tobago' 'Tunisia' 'Turkmenistan' 'Turks and Caicos Islands'
#  'Tuvalu' 'Uganda' 'Ukraine' 'United Arab Emirates' 'United Kingdom'
#  'United States' 'Uruguay' 'Uzbekistan' 'Vanuatu' 'World' 'Zambia'
#  'Zimbabwe']

# %%
# -------------------------------
# 4. Filter by Year and Country
# -------------------------------
# Keep years >= 1965 (reliable coverage)
df_selected = df_selected[df_selected["year"] >= 1965]

# Drop countries with >40% missing
threshold = 0.4
country_missing = df_selected.groupby("country").apply(lambda x: x.isna().mean().mean())
good_countries = country_missing[country_missing <= threshold].index
df_selected = df_selected[df_selected["country"].isin(good_countries)]

# Drop aggregate entries
df_selected = df_selected.drop(df_selected[df_selected['country'].isin(['World', 'North America'])].index)
# Out:
# /tmp/ipykernel_4381/2822749616.py:9: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   country_missing = df_selected.groupby("country").apply(lambda x: x.isna().mean().mean())

# %%
# -------------------------------
# 5. Drop rows with missing target
# -------------------------------
df_selected = df_selected.dropna(subset=['energy_per_capita']).copy()

# %%
df_selected.isna().mean().sort_values(ascending=False)
# Out:
# gdp_per_capita                  0.041441
# gdp                             0.041441
# renewables_share_energy         0.001544
# hydro_share_energy              0.001544
# wind_share_energy               0.001544
# fossil_share_energy             0.001544
# low_carbon_share_energy         0.001544
# solar_share_energy              0.001544
# year                            0.000000
# country                         0.000000
# fossil_energy_per_capita        0.000000
# oil_energy_per_capita           0.000000
# gas_energy_per_capita           0.000000
# coal_cons_per_capita            0.000000
# population                      0.000000
# energy_per_capita               0.000000
# renewables_energy_per_capita    0.000000
# low_carbon_energy_per_capita    0.000000
# dtype: float64

# %%
# -------------------------------
# 6. Missing Value Imputation
# -------------------------------
# Sort by country/year first
df_selected = df_selected.sort_values(['country', 'year'])

# Interpolate GDP features
gdp_cols = ["gdp", "gdp_per_capita"]
df_selected[gdp_cols] = df_selected.groupby("country")[gdp_cols].transform(
    lambda x: x.interpolate().ffill().bfill()
)

# Forward/backward fill energy share features
share_cols = [
    "renewables_share_energy", "hydro_share_energy", "wind_share_energy",
    "fossil_share_energy", "low_carbon_share_energy", "solar_share_energy"
]
df_selected[share_cols] = df_selected.groupby("country")[share_cols].transform(
    lambda x: x.ffill().bfill()
)

# %%
# -------------------------------
# 7. Final Check
# -------------------------------
print("Missing values per column after imputation:")
print(df_selected.isna().sum())

print("\nDataset shape:", df_selected.shape)
print("Number of countries:", df_selected['country'].nunique())
# Out:
# Missing values per column after imputation:
# country                         0
# year                            0
# population                      0
# gdp                             0
# energy_per_capita               0
# coal_cons_per_capita            0
# gas_energy_per_capita           0
# oil_energy_per_capita           0
# fossil_energy_per_capita        0
# fossil_share_energy             0
# renewables_energy_per_capita    0
# low_carbon_energy_per_capita    0
# renewables_share_energy         0
# low_carbon_share_energy         0
# hydro_share_energy              0
# solar_share_energy              0
# wind_share_energy               0
# gdp_per_capita                  0
# dtype: int64
#
# Dataset shape: (3885, 18)
# Number of countries: 69
